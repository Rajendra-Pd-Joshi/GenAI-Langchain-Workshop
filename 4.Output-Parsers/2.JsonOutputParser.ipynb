# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

# %%
parser = JsonOutputParser()

# %%
prompt = PromptTemplate(
    template='give me a 5 lines about the batting class of {batsman}\n{format_instruction}',
    input_variables=['batsman'],
    partial_variables={'format_instruction':parser.get_format_instructions()}
)

# %%
chain = prompt | model | parser

# %%
result = chain.invoke(input = {
    'batsman':'steve smith'
})

# %%
print(result)
# Out:
# {'player': 'Steve Smith', 'class': "The batting class of Steve Smith is unmatched, with his unorthodox style and impeccable technique setting him apart from the rest. His ability to read the game and adapt to different situations make him a formidable opponent for any bowler. Smith's wristy flicks and precise footwork make him a joy to watch, as he effortlessly manipulates the field with his placement and timing. His consistency and determination at the crease have earned him the reputation as one of the best batsmen in the world. Smith's unique approach to batting makes him a true cricketing genius, capable of turning any match in his team's favor with his skill and temperament."}

# %%
print(type(result))
# Out:
# <class 'dict'>

# %% [markdown]
# ### the biggest draw back of the json output parser is we cannot enforce the schema to follow

# %% [markdown]
# ### Strength is it give the class dict i.e data in json format i.e universally accepted
