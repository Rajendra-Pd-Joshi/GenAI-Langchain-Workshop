# %%
from typing import TypedDict

class Person(TypedDict):
    name : str
    age : int

# %%
new_person : Person ={
    'name':'raju',
    'age':23
}

# %%
print(new_person)
# Out:
# {'name': 'raju', 'age': 23}

# %% [markdown]
# ### sentiment analysis of the review using typed dict

# %%
from langchain_openai import ChatOpenAI
from typing import TypedDict

# %%
class Review(TypedDict):
    summary : str
    sentiment : str

# %%
model = ChatOpenAI(model = 'gpt-4o-mini')
structured_model = model.with_structured_output(schema=Review)

# %%
structured_model.invoke("""I recently upgraded to the Samsung Galaxy S24 Ultra, and I must say, it’s an absolute powerhouse! The Snapdragon 8 Gen 3 processor makes everything lightning fast—whether I’m gaming, multitasking, or editing photos. The 5000mAh battery easily lasts a full day even with heavy use, and the 45W fast charging is a lifesaver.

The S-Pen integration is a great touch for note-taking and quick sketches, though I don't use it often. What really blew me away is the 200MP camera—the night mode is stunning, capturing crisp, vibrant images even in low light. Zooming up to 100x actually works well for distant objects, but anything beyond 30x loses quality.

However, the weight and size make it a bit uncomfortable for one-handed use. Also, Samsung’s One UI still comes with bloatware—why do I need five different Samsung apps for things Google already provides? The $1,300 price tag is also a hard pill to swallow.

Pros:
Insanely powerful processor (great for gaming and productivity)
Stunning 200MP camera with incredible zoom capabilities
Long battery life with fast charging
S-Pen support is unique and useful
                                 
Review by Raju Joshi
""")
# Out:
# {'summary': 'The Samsung Galaxy S24 Ultra is a high-performance smartphone with an impressive Snapdragon 8 Gen 3 processor, a stunning 200MP camera, and long-lasting battery life, though its weight and bloatware could be drawbacks for some users.',
#  'sentiment': 'positive'}

# %% [markdown]
# ### some time we need more description at the time of the schema definition so use annotated

# %%
from langchain_openai import ChatOpenAI
from typing import TypedDict,Annotated

# %%
class Review(TypedDict):
    summary : Annotated[str,'a brief summary of the review including all aspect present']
    sentiment : Annotated[str,'choose a sentiment either positive or negative or neutral']

# %%
model = ChatOpenAI(model = 'gpt-4o-mini')
structured_model = model.with_structured_output(schema=Review)

# %%
structured_model.invoke("""I recently upgraded to the Samsung Galaxy S24 Ultra, and I must say, it’s an absolute powerhouse! The Snapdragon 8 Gen 3 processor makes everything lightning fast—whether I’m gaming, multitasking, or editing photos. The 5000mAh battery easily lasts a full day even with heavy use, and the 45W fast charging is a lifesaver.

The S-Pen integration is a great touch for note-taking and quick sketches, though I don't use it often. What really blew me away is the 200MP camera—the night mode is stunning, capturing crisp, vibrant images even in low light. Zooming up to 100x actually works well for distant objects, but anything beyond 30x loses quality.

However, the weight and size make it a bit uncomfortable for one-handed use. Also, Samsung’s One UI still comes with bloatware—why do I need five different Samsung apps for things Google already provides? The $1,300 price tag is also a hard pill to swallow.

Pros:
Insanely powerful processor (great for gaming and productivity)
Stunning 200MP camera with incredible zoom capabilities
Long battery life with fast charging
S-Pen support is unique and useful
                                 
Review by Raju Joshi
""")
# Out:
# {'summary': 'The Samsung Galaxy S24 Ultra is an impressive device with a powerful Snapdragon 8 Gen 3 processor, excellent battery life, and a phenomenal 200MP camera. While the S-Pen is a useful addition and the phone is capable of handling demanding tasks with ease, it does feel bulky for one-handed use and comes with some pre-installed bloatware. The high price may also deter potential buyers.',
#  'sentiment': 'positive'}

# %% [markdown]
# #### There is a concept of optional,Literal and many more in typed dict lets see one by one

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from typing import TypedDict,Annotated,Literal,Optional

# %%
class Review(TypedDict):
    key_themes : Annotated[list[str],'write down all the key themes present here in the review']
    summary : Annotated[str,'write down a 5 line summary for the review']
    sentiment : Annotated[Literal['pos','neg'],'what is the sentiment of the review']
    pros : Annotated[Optional[list[str]],'write down all the pros mentioned in the review']
    cons : Annotated[Optional[list[str]],'write down all the cons mentioned in the review']
    name: Annotated[Optional[str],'write down the name of the reviewer who wrote the review']

# %%
model = ChatOpenAI(model='gpt-4o-mini')
structured_model = model.with_structured_output(schema = Review)

# %%
structured_model.invoke("""I recently upgraded to the Samsung Galaxy S24 Ultra, and I must say, it’s an absolute powerhouse! The Snapdragon 8 Gen 3 processor makes everything lightning fast—whether I’m gaming, multitasking, or editing photos. The 5000mAh battery easily lasts a full day even with heavy use, and the 45W fast charging is a lifesaver.

The S-Pen integration is a great touch for note-taking and quick sketches, though I don't use it often. What really blew me away is the 200MP camera—the night mode is stunning, capturing crisp, vibrant images even in low light. Zooming up to 100x actually works well for distant objects, but anything beyond 30x loses quality.

However, the weight and size make it a bit uncomfortable for one-handed use. Also, Samsung’s One UI still comes with bloatware—why do I need five different Samsung apps for things Google already provides? The $1,300 price tag is also a hard pill to swallow.

Pros:
Insanely powerful processor (great for gaming and productivity)
Stunning 200MP camera with incredible zoom capabilities
Long battery life with fast charging
S-Pen support is unique and useful
                                 
Review by Raju Joshi
""")
# Out:
# {'name': 'Samsung Galaxy S24 Ultra Review',
#  'summary': 'The Samsung Galaxy S24 Ultra is an exceptional device that combines powerful performance, impressive camera capabilities, and a long-lasting battery. While it excels in many areas, its size and bloatware may deter some users.',
#  'sentiment': 'pos',
#  'pros': ['Insanely powerful processor (great for gaming and productivity)',
#   'Stunning 200MP camera with incredible zoom capabilities',
#   'Long battery life with fast charging',
#   'S-Pen support is unique and useful'],
#  'cons': ['Heavy and large for one-handed use',
#   "Samsung's One UI features too much bloatware",
#   'High price point at $1,300'],
#  'key_themes': ['Performance',
#   'Camera Quality',
#   'Battery Life',
#   'User Experience']}

# %% [markdown]
# #### But the problem with the typed dict is we can only define the schema and tell llm to follow that but we can't validate that wheather the output is accroding to the schema or not for that we have to read the pydantic
