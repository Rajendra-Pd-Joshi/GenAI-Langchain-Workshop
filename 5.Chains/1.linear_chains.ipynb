# %% [markdown]
# ## Sequential Chain

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt1 = PromptTemplate(
    template = 'give me a breif in detail about the {batsman} career',
    input_variables= ['batsman']
)

# %%
model = ChatOpenAI(model='gpt-4o-mini')

# %%
parser = StrOutputParser()

# %%
prompt2 = PromptTemplate(
    template='give me the 5 intresting fact about this report {report}',
    input_variables=['report']
)

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
response = chain.invoke(input ={'batsman':'steve smith'})

# %%
print(response)
# Out:
# Here are five interesting facts about Steve Smith based on the report:
#
# 1. **Unorthodox Start**: Steve Smith began his career as a leg-spin bowler and a lower-order batsman. His initial role in the Australian Test team was primarily to contribute as a bowler, which is quite different from his current status as one of the world's leading batsmen.
#
# 2. **Record-Breaking Average**: Smith has maintained a remarkable batting average of over 60 in Test cricket, situating him among the elite cricketers worldwide. This high average is a testament to his consistency and ability to perform under pressure.
#
# 3. **Transformation into a Batsman**: Smith's career trajectory transformed dramatically around 2013. He moved from being primarily a bowler to becoming a key batting figure in the Australian team, showcasing his adaptability and determination.
#
# 4. **Multi-Faceted Achievements**: Beyond his exceptional batting, Smith has earned numerous prestigious awards, including the ICC Cricketer of the Year and the ICC Test Player of the Year, solidifying his reputation as one of the best in the sport.
#
# 5. **Resilient Comeback**: Following his one-year ban due to the ball-tampering scandal, Smith made a noteworthy return to cricket during the Ashes series in 2019. His performance was instrumental in Australia’s success, highlighting his resilience and ability to bounce back from setbacks.
