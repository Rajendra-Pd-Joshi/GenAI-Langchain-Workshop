# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()
model.invoke('who is the prime minister of Nepal').content
# Out:
# 'Sher Bahadur Deuba is the current Prime Minister of Nepal.'

# %% [markdown]
# ## What is the Temperature parameter ranges bewteen 0 to 2

# %%
model = ChatOpenAI(model_name= "gpt-4o-mini", temperature=0)
poem = model.invoke('write a poem about steve smith batting class').content
print(poem)
# Out:
# In the heart of the crease, where legends are born,
# Stands a maestro of willow, in sunlight and storm.
# With a shuffle and sway, he dances with grace,
# Steve Smith, the artist, in his batting embrace.
#
# His stance, unorthodox, a sight to behold,
# A story of courage, of passion, and bold.
# With eyes like a hawk, he surveys the field,
# In the battle of cricket, his spirit won’t yield.
#
# The bowler approaches, the crowd holds its breath,
# With each ball that’s bowled, he flirts with death.
# A flick of the wrist, a stroke so divine,
# The ball races past, like a whisper of time.
#
# He crafts his own rhythm, a symphony sweet,
# With footwork like poetry, he dances on feet.
# A flick to the leg, a drive through the air,
# In the theater of cricket, he’s beyond compare.
#
# The scoreboard ticks over, the runs start to flow,
# With patience and skill, he steals the show.
# A hundred, a double, the milestones he claims,
# In the annals of cricket, forever his name.
#
# But it’s more than the numbers, the records, the fame,
# It’s the heart of the game, the love of the flame.
# For every young dreamer who picks up a bat,
# Steve Smith’s a reminder: it’s more than just that.
#
# So here’s to the class, the elegance, flair,
# To the battles he’s fought, to the moments we share.
# In the tapestry woven of cricket’s grand lore,
# Steve Smith, the batsman, we’ll always adore.

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
model .invoke('who is the pm of nepal?').content
# Out:
# 'As of October 2021, the Prime Minister of Nepal is Sher Bahadur Deuba.'

# %%
model = ChatOpenAI(model_name= "gpt-4o-mini", temperature=0)
poem = model.invoke('write a poem about steve smith batting class').content
print(poem)
# Out:
# In the heart of the crease, where legends are born,
# Stands a figure of grace, in the light of the dawn.
# With a bat in his hand and a glint in his eye,
# Steve Smith takes guard, as the bowlers all sigh.
#
# His stance is unique, a dance of its own,
# A shuffle, a twitch, like a king on his throne.
# With a mind like a fortress, he reads every ball,
# In the theater of cricket, he’s the star of it all.
#
# The bowler runs in, with a roar and a rush,
# But Smith’s calm demeanor turns pressure to hush.
# With a flick of the wrist, he sends leather to sky,
# A symphony of strokes, as the crowd starts to cry.
#
# The cover drive glistens, like sunlight on dew,
# Each shot tells a story, each run feels brand new.
# He weaves through the fielders, a magician at play,
# In the art of batting, he’s the master, they say.
#
# With patience as virtue, he builds his domain,
# In the realm of the cricket, he dances through pain.
# A warrior of will, with a heart made of steel,
# In the saga of sport, it’s his spirit we feel.
#
# So here’s to the man, with his unorthodox flair,
# In the annals of cricket, he’s beyond compare.
# For every sweet moment, every glorious hit,
# Steve Smith’s batting class is a timeless exhibit.

# %%
model = ChatOpenAI(model_name= "gpt-4o-mini", temperature=1.5)
poem = model.invoke('write a 5 line poem about steve smith batting class').content
print(poem)
