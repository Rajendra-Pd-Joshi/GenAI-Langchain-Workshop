# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()
model.invoke('who is the prime minister of Nepal').content
# Out:
# 'Sher Bahadur Deuba is the current Prime Minister of Nepal.'

# %% [markdown]
# ## What is the Temperature parameter ranges bewteen 0 to 2

# %%
model = ChatOpenAI(model_name= "gpt-4o-mini", temperature=0.5)
poem = model.invoke('write a poem about steve smith batting class').content
print(poem)
# Out:
# In the arena where legends are born,
# With a bat in hand, the crowd's hearts are torn,
# Steve Smith strides forth, a sight to behold,
# A master of patience, a warrior bold.
#
# His stance, unorthodox, a dance of its own,
# With a flick of the wrist, the seeds are sown,
# Each ball a canvas, each stroke a brush,
# In the symphony of cricket, he brings the hush.
#
# The bowler approaches, intent on his prey,
# But Smith stands his ground, come what may,
# With footwork like poetry, he glides to the pitch,
# In the heart of the battle, he finds his niche.
#
# A flick to the leg, a drive through the off,
# With every sweet connection, the critics scoff,
# For they cannot see what lies in his mind,
# A strategy woven, a brilliance defined.
#
# Through trials and tempests, he’s weathered the storm,
# In the crucible of cricket, his spirit takes form,
# With grit in his heart and a fire in his eyes,
# He dances with fate, as the ball swiftly flies.
#
# ...
